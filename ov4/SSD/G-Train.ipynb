# %%
# !kill 1030

# %%
# %load_ext tensorboard
# %tensorboard --logdir output
# Out:
# The tensorboard extension is already loaded. To reload it, use:
#   %reload_ext tensorboard
#       <iframe id="tensorboard-frame-3b8dfe246b017c58" width="100%" height="800" frameborder="0">
#       </iframe>
#       <script>
#         (function() {
#           const frame = document.getElementById("tensorboard-frame-3b8dfe246b017c58");
#           const url = new URL("/", window.location);
#           const port = 6006;
#           if (port) {
#             url.port = port;
#           }
#           frame.src = url;
#         })();
#       </script>

# %%
# %run train.py  configs/mnist_tdt4265_server.yaml
# Out:
# 2021-03-17 16:15:26,305 SSD INFO: Namespace(config_file='configs/mnist_tdt4265_server.yaml', opts=[])
# 2021-03-17 16:15:26,307 SSD INFO: Loaded configuration file configs/mnist_tdt4265_server.yaml
# 2021-03-17 16:15:26,309 SSD INFO:
# MODEL:
#     NUM_CLASSES: 11
#     BACKBONE:
#         NAME: 'basic'
#         PRETRAINED: False
#         OUT_CHANNELS: [128, 256, 128, 128, 64, 64]
#         INPUT_CHANNELS: 3
# INPUT:
#     IMAGE_SIZE: [300, 300]
# DATASETS:
#     TRAIN: ("mnist_detection_train", "mnist_detection_val")
#     TEST: ("mnist_detection_val", )
# SOLVER:
#     MAX_ITER: 10000
#     GAMMA: 0.1
#     BATCH_SIZE: 16
#     LR: 2e-3
# OUTPUT_DIR: 'outputs/basic'
# DATASET_DIR: "/work/datasets"
# 2021-03-17 16:15:26,310 SSD INFO: Running with config:
# DATASETS:
#   TEST: ('mnist_detection_val',)
#   TRAIN: ('mnist_detection_train', 'mnist_detection_val')
# DATASET_DIR: /work/datasets
# DATA_LOADER:
#   NUM_WORKERS: 4
#   PIN_MEMORY: True
# EVAL_STEP: 500
# INPUT:
# ...

# %%
# %run test.py configs/mnist_tdt4265_server.yaml
# Out:
# 2021-03-17 15:13:15,524 SSD INFO: Namespace(ckpt=None, config_file='configs/mnist_tdt4265_server.yaml', opts=[], output_dir='eval_results')
# 2021-03-17 15:13:15,524 SSD INFO: Namespace(ckpt=None, config_file='configs/mnist_tdt4265_server.yaml', opts=[], output_dir='eval_results')
# 2021-03-17 15:13:15,524 SSD INFO: Namespace(ckpt=None, config_file='configs/mnist_tdt4265_server.yaml', opts=[], output_dir='eval_results')
# 2021-03-17 15:13:15,524 SSD INFO: Namespace(ckpt=None, config_file='configs/mnist_tdt4265_server.yaml', opts=[], output_dir='eval_results')
# 2021-03-17 15:13:15,530 SSD INFO: Loaded configuration file configs/mnist_tdt4265_server.yaml
# 2021-03-17 15:13:15,530 SSD INFO: Loaded configuration file configs/mnist_tdt4265_server.yaml
# 2021-03-17 15:13:15,530 SSD INFO: Loaded configuration file configs/mnist_tdt4265_server.yaml
# 2021-03-17 15:13:15,530 SSD INFO: Loaded configuration file configs/mnist_tdt4265_server.yaml
# 2021-03-17 15:13:15,535 SSD INFO:
# MODEL:
# ...
